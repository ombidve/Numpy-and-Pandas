# %%
import numpy as np

# %%
import pandas as pd

# %%
food = pd.read_csv('indian_food.csv')

# %%
food.head(10)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian         45         25          sweet  dessert    West Bengal
# 1  vegetarian         80         30          sweet  dessert      Rajasthan
# 2  vegetarian         15         60          sweet  dessert         Punjab
# 3  vegetarian         15         30          sweet  dessert      Rajasthan
# 4  vegetarian         15         40          sweet  dessert    West Bengal
# 5  vegetarian         10         50          sweet  dessert    West Bengal
# 6  vegetarian         10         50          sweet  dessert  Uttar Pradesh
# 7  vegetarian         10         20          sweet  dessert             -1
# 8  vegetarian         20         30          sweet  dessert    West Bengal
# 9  vegetarian         10         40          sweet  dessert             -1
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East
# 5   East
# 6  North
# 7     -1
# 8   East
# 9     -1

# %%
# pivot dataframes

# %%
food.shape
# Out:
# (255, 9)

# %%
food.pivot_table(index='name', columns='state', values='cook_time', aggfunc='mean')
# Out:
# state                 -1  Andhra Pradesh  Assam  Bihar  Chhattisgarh   Goa  \
# name
# Adhirasam            NaN             NaN    NaN    NaN           NaN   NaN
# Aloo gobi            NaN             NaN    NaN    NaN           NaN   NaN
# Aloo matar           NaN             NaN    NaN    NaN           NaN   NaN
# Aloo methi           NaN             NaN    NaN    NaN           NaN   NaN
# Aloo shimla mirch    NaN             NaN    NaN    NaN           NaN   NaN
# ...                  ...             ...    ...    ...           ...   ...
# Vada                20.0             NaN    NaN    NaN           NaN   NaN
# Veg Kolhapuri        NaN             NaN    NaN    NaN           NaN   NaN
# Vegetable jalfrezi   NaN             NaN    NaN    NaN           NaN   NaN
# Vindaloo             NaN             NaN    NaN    NaN           NaN  40.0
# Zunka                NaN             NaN    NaN    NaN           NaN   NaN
#
# state               Gujarat  Haryana  Jammu & Kashmir  Karnataka  ...  \
# name                                                              ...
# Adhirasam               NaN      NaN              NaN        NaN  ...
# Aloo gobi               NaN      NaN              NaN        NaN  ...
# Aloo matar              NaN      NaN              NaN        NaN  ...
# Aloo methi              NaN      NaN              NaN        NaN  ...
# Aloo shimla mirch       NaN      NaN              NaN        NaN  ...
# ...                     ...      ...              ...        ...  ...
# Vada                    NaN      NaN              NaN        NaN  ...
# Veg Kolhapuri           NaN      NaN              NaN        NaN  ...
# Vegetable jalfrezi      NaN      NaN              NaN        NaN  ...
# Vindaloo                NaN      NaN              NaN        NaN  ...
# Zunka                   NaN      NaN              NaN        NaN  ...
#
# state               Nagaland  Odisha  Punjab  Rajasthan  Tamil Nadu  \
# name
# Adhirasam                NaN     NaN     NaN        NaN         NaN
# Aloo gobi                NaN     NaN    20.0        NaN         NaN
# Aloo matar               NaN     NaN    40.0        NaN         NaN
# Aloo methi               NaN     NaN    40.0        NaN         NaN
# Aloo shimla mirch        NaN     NaN    40.0        NaN         NaN
# ...                      ...     ...     ...        ...         ...
# Vada                     NaN     NaN     NaN        NaN         NaN
# Veg Kolhapuri            NaN     NaN     NaN        NaN         NaN
# Vegetable jalfrezi       NaN     NaN    30.0        NaN         NaN
# Vindaloo                 NaN     NaN     NaN        NaN         NaN
# Zunka                    NaN     NaN     NaN        NaN         NaN
#
# state               Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# name
# Adhirasam                 NaN      NaN            NaN          NaN
# Aloo gobi                 NaN      NaN            NaN          NaN
# Aloo matar                NaN      NaN            NaN          NaN
# Aloo methi                NaN      NaN            NaN          NaN
# Aloo shimla mirch         NaN      NaN            NaN          NaN
# ...                       ...      ...            ...          ...
# Vada                      NaN      NaN            NaN          NaN
# Veg Kolhapuri             NaN      NaN            NaN          NaN
# Vegetable jalfrezi        NaN      NaN            NaN          NaN
# Vindaloo                  NaN      NaN            NaN          NaN
# Zunka                     NaN      NaN            NaN          NaN
#
# state               West Bengal
# name
# Adhirasam                  50.0
# Aloo gobi                   NaN
# Aloo matar                  NaN
# Aloo methi                  NaN
# Aloo shimla mirch           NaN
# ...                         ...
# Vada                        NaN
# Veg Kolhapuri               NaN
# Vegetable jalfrezi          NaN
# Vindaloo                    NaN
# Zunka                       NaN
#
# [255 rows x 25 columns]

# %%
food.pivot_table(index='name', columns=['region','state'], values=['cook_time','prep_time'], aggfunc='mean')
# Out:
#                    cook_time                                                 \
# region                    -1      Central                  East
# state                     -1 Chhattisgarh Madhya Pradesh Odisha West Bengal
# name
# Adhirasam                NaN          NaN            NaN    NaN        50.0
# Aloo gobi                NaN          NaN            NaN    NaN         NaN
# Aloo matar               NaN          NaN            NaN    NaN         NaN
# Aloo methi               NaN          NaN            NaN    NaN         NaN
# Aloo shimla mirch        NaN          NaN            NaN    NaN         NaN
# ...                      ...          ...            ...    ...         ...
# Vada                     NaN          NaN            NaN    NaN         NaN
# Veg Kolhapuri            NaN          NaN            NaN    NaN         NaN
# Vegetable jalfrezi       NaN          NaN            NaN    NaN         NaN
# Vindaloo                 NaN          NaN            NaN    NaN         NaN
# Zunka                    NaN          NaN            NaN    NaN         NaN
#
#                                                                      ...  \
# region             North                                             ...
# state                 -1 Bihar Haryana Jammu & Kashmir NCT of Delhi  ...
# name                                                                 ...
# Adhirasam            NaN   NaN     NaN             NaN          NaN  ...
# Aloo gobi            NaN   NaN     NaN             NaN          NaN  ...
# Aloo matar           NaN   NaN     NaN             NaN          NaN  ...
# Aloo methi           NaN   NaN     NaN             NaN          NaN  ...
# Aloo shimla mirch    NaN   NaN     NaN             NaN          NaN  ...
# ...                  ...   ...     ...             ...          ...  ...
# Vada                 NaN   NaN     NaN             NaN          NaN  ...
# Veg Kolhapuri        NaN   NaN     NaN             NaN          NaN  ...
# Vegetable jalfrezi   NaN   NaN     NaN             NaN          NaN  ...
# Vindaloo             NaN   NaN     NaN             NaN          NaN  ...
# Zunka                NaN   NaN     NaN             NaN          NaN  ...
#
#                    prep_time                                             \
# region                 South
# state                     -1 Andhra Pradesh Karnataka Kerala Tamil Nadu
# name
# Adhirasam                NaN            NaN       NaN    NaN        NaN
# Aloo gobi                NaN            NaN       NaN    NaN        NaN
# Aloo matar               NaN            NaN       NaN    NaN        NaN
# Aloo methi               NaN            NaN       NaN    NaN        NaN
# Aloo shimla mirch        NaN            NaN       NaN    NaN        NaN
# ...                      ...            ...       ...    ...        ...
# Vada                    15.0            NaN       NaN    NaN        NaN
# Veg Kolhapuri            NaN            NaN       NaN    NaN        NaN
# Vegetable jalfrezi       NaN            NaN       NaN    NaN        NaN
# Vindaloo                 NaN            NaN       NaN    NaN        NaN
# Zunka                    NaN            NaN       NaN    NaN        NaN
#
#
# region                        West
# state              Telangana   Goa Gujarat Maharashtra Rajasthan
# name
# Adhirasam                NaN   NaN     NaN         NaN       NaN
# Aloo gobi                NaN   NaN     NaN         NaN       NaN
# Aloo matar               NaN   NaN     NaN         NaN       NaN
# Aloo methi               NaN   NaN     NaN         NaN       NaN
# Aloo shimla mirch        NaN   NaN     NaN         NaN       NaN
# ...                      ...   ...     ...         ...       ...
# Vada                     NaN   NaN     NaN         NaN       NaN
# Veg Kolhapuri            NaN   NaN     NaN        20.0       NaN
# Vegetable jalfrezi       NaN   NaN     NaN         NaN       NaN
# Vindaloo                 NaN  10.0     NaN         NaN       NaN
# Zunka                    NaN   NaN     NaN        10.0       NaN
#
# [254 rows x 54 columns]
